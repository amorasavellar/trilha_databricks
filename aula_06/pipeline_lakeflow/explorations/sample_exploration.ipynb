# %% [markdown]
# ### Notebook de Exploração - Pipeline Claims
#
# Use este notebook para explorar os dados gerados pelo pipeline DLT.
#
# **Nota**: Este notebook não é executado como parte do pipeline.
#
# **Catálogo**: smart_claims_dev

# %% [markdown]
# ### Explorar Camada Bronze (01_bronze)

# %%
# %sql
-- Explorar dados de customers
SELECT * FROM smart_claims_declarative_pipeline.01_bronze.customers LIMIT 10;

# %%
# %sql
-- Explorar dados de policies
SELECT * FROM smart_claims_declarative_pipeline.01_bronze.policies LIMIT 10;

# %%
# %sql
-- Explorar dados de claims
SELECT COUNT(*) AS total_claims FROM smart_claims_declarative_pipeline.01_bronze.claims;
SELECT * FROM smart_claims_declarative_pipeline.01_bronze.claims LIMIT 10;

# %% [markdown]
# ### Explorar Camada Silver (02_silver)

# %%
# %sql
-- Explorar claims enriquecidos
SELECT * FROM smart_claims_declarative_pipeline.02_silver.claims_enriched LIMIT 10;

# %%
# %sql
-- Verificar total de registros enriquecidos
SELECT COUNT(*) AS total_enriched FROM smart_claims_declarative_pipeline.02_silver.claims_enriched;

# %% [markdown]
# ### Explorar Camada Gold (03_gold)

# %%
# %sql
-- Consultar métricas agregadas
SELECT * FROM smart_claims_declarative_pipeline.03_gold.claims_metrics;
